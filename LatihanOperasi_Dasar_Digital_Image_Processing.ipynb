# %% [markdown]
# <a href="https://colab.research.google.com/github/Intanpratiwiiii/Intann/blob/main/LatihanOperasi_Dasar_Digital_Image_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# library
import urllib.request
import cv2 # https://docs.opencv.org/4.x/d6/d00/tutorial_py_root.html
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Load Image

# %%
# get image from link google image

# first Image
urllib.request.urlretrieve(
'data:image/jpeg;base64,...', # link from google image
"gambar_1.png")

# Second Image
urllib.request.urlretrieve(
'data:image/jpeg;base64,...', # link from google image
"gambar_2.png")
# Out:
# ('gambar_2.png', <email.message.Message at 0x7e78e0492380>)

# %% [markdown]
# Arithmetic Operations in Digital Image Processing

# %%
# load image
image_1 = cv2.imread('gambar_1.png') # cv2.IMREAD_GRAYSCALE
image_2 = cv2.imread('gambar_2.png')

# Dapatkan resolusi gambar dalam piksel
width, height,channel = image_1.shape
print(f"Resolusi gambar 1: {width}x{height}x{channel} piksel")

# Dapatkan resolusi gambar dalam piksel
width_2, height_2,channel_2 = image_2.shape
print(f"Resolusi gambar 2: {width_2}x{height_2}x{channel_2} piksel")
# Out:
# Resolusi gambar 1: 183x275x3 piksel
# Resolusi gambar 2: 180x279x3 piksel

# %%
# plot figure
plt.figure(figsize=(8,4))

plt.subplot(1, 2, 1)
plt.imshow(image_1)
plt.title("Gambar satu")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image_2)
plt.title("Gambar dua")
plt.axis('off')

plt.show()

# %%
image_1 = cv2.resize(image_1,(180,270))
image_2 = cv2.resize(image_2,(180,270))

# %% [markdown]
# Image Addition

# %%
# hasil gambar Addition
result_add = cv2.add(image_1, image_2)
plt.imshow(result_add)
plt.show()

# Dapatkan resolusi gambar dalam piksel
width, height,channel = result_add.shape
print(f"Resolusi gambar 1: {width}x{height}x{channel} piksel")
# Out:
# Resolusi gambar 1: 270x180x3 piksel

# %%
# Membandingkan data piksel
print("Image 1 Shape: ", image_1.shape)
print("Image 2 Shape: ", image_2.shape)
print("Result Image Shape: ", result_add.shape)

# Jika ingin melihat beberapa piksel untuk perbandingan, ambil subset data
image1_pixels = image_1[:5,:5,0]  # Ambil 5x5 bagian atas dari gambar 1 #channel blue
image2_pixels = image_2[:5,:5,0]  # Ambil 5x5 bagian atas dari gambar 2 #channel blue
image3_pixels = result_add[:5, :5, 0]  # Ambil 5x5 bagian atas dari gambar 2 #channel blue

print("\nData Piksel Gambar satu \n", image1_pixels)
print("\nData Piksel Gambar dua \n", image2_pixels)
print("\nData Piksel Gambar tiga \n", image3_pixels)
# Out:
# Image 1 Shape:  (270, 180, 3)
# Image 2 Shape:  (270, 180, 3)
# Result Image Shape:  (270, 180, 3)
#
# Data Piksel Gambar satu
#  [[118 120 120 117 112]
#  [123 125 125 121 116]
#  [130 132 131 127 122]
#  [139 140 139 134 129]
#  [146 147 145 140 134]]
#
# Data Piksel Gambar dua
#  [[111 111 112 112 113]
#  [112 112 112 113 114]
#  [112 112 112 113 114]
#  [113 113 114 115 115]
#  [114 114 115 115 116]]
#
# Data Piksel Gambar tiga
#  [[229 231 232 229 225]
#  [235 237 237 234 230]
#  [242 244 243 240 236]
#  [252 253 253 249 244]
#  [255 255 255 255 250]]

# %% [markdown]
# Logical Operations in Digital Image Processing

# %% [markdown]
# # Load Image

# %% [markdown]
# # Bagian Baru

# %%
# # # load image
# image1_logical = cv2.imread('gambar_1_logical.png')
# image2_logical = cv2.imread('gambar_2_logical.png')

# Dapatkan resolusi gambar dalam piksel
width, height,channel = image_1.shape
print(f"Resolusi gambar 1: {width}x{height}x{channel} piksel")

# Dapatkan resolusi gambar dalam piksel
width_2, height_2,channel_2 = image_2.shape
print(f"Resolusi gambar 2: {width_2}x{height_2}x{channel_2} piksel")
# Out:
# Resolusi gambar 1: 270x180x3 piksel
# Resolusi gambar 2: 270x180x3 piksel

# %%
# plot figure
plt.figure(figsize=(8,4))

plt.subplot(1, 2, 1)
plt.imshow(image_1, cmap='gray')
plt.title("Gambar satu")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(image_2, cmap='gray')
plt.title("Gambar dua")
plt.axis('off')

plt.show()

# %% [markdown]
# # OR

# %%
# hasil gambar Addition)
result_logical = cv2.bitwise_or(image_1,image_2)
plt.imshow(result_logical)
plt.show()

# Dapatkan resolusi gambar dalam piksel
width, height, channel = result_logical.shape
print(f"Resolusi gambar 1: {width}x{height}x{channel} piksel")
# Out:
# Resolusi gambar 1: 270x180x3 piksel

# %%
# Membandingkan data piksel
print("Image 1 Shape: ", image_1.shape)
print("Image 2 Shape: ", image_2.shape)
print("Result Image Shape: ", result_logical.shape)

# Jika ingin melihat beberapa piksel untuk perbandingan, ambil subset data
image1_pixels_logical = image_1[:5, :5, 0]  # Ambil 5x5 bagian atas dari gambar 1 (channel blue)
image2_pixels_logical = image_2[:5, :5, 0]  # Ambil 5x5 bagian atas dari gambar 2 (channel blue)
image3_pixels_logical = result_logical[:5, :5, 0]  # Ambil 5x5 bagian atas dari gambar hasil (channel blue)

# Cetak data piksel untuk setiap gambar
print("\nData Piksel Gambar satu: \n", image1_pixels_logical)
print("\nData Piksel Gambar dua: \n", image2_pixels_logical)
print("\nData Piksel Gambar hasil (logical): \n", image3_pixels_logical)
# Out:
# Image 1 Shape:  (270, 180, 3)
# Image 2 Shape:  (270, 180, 3)
# Result Image Shape:  (270, 180, 3)
#
# Data Piksel Gambar satu:
#  [[118 120 120 117 112]
#  [123 125 125 121 116]
#  [130 132 131 127 122]
#  [139 140 139 134 129]
#  [146 147 145 140 134]]
#
# Data Piksel Gambar dua:
#  [[111 111 112 112 113]
#  [112 112 112 113 114]
#  [112 112 112 113 114]
#  [113 113 114 115 115]
#  [114 114 115 115 116]]
#
# Data Piksel Gambar hasil (logical):
#  [[127 127 120 117 113]
#  [123 125 125 121 118]
#  [242 244 243 127 122]
#  [251 253 251 247 243]
#  [242 243 243 255 246]]

# %%
# hasil gambar Addition
result_logical = cv2.bitwise_and(image_1, image_2)
plt.imshow(result_logical)
plt.show()


# Dapatkan resolusi gambar dalam piksel
width, height,channel = result_logical.shape
print(f"Resolusi gambar 1: {width}x{height}x{channel} piksel")
# Out:
# Resolusi gambar 1: 270x180x3 piksel

# %% [markdown]
# ## Geomatrik Operation Latihan

# %%
# library
import urllib.request
import cv2 # https://docs.opencv.org/4.x/d6/d00/tutorial_py_root.html
import matplotlib.pyplot as plt
import numpy as np

# %%
# get image from link google image

# first Image
urllib.request.urlretrieve('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSfLJKt1a85bo4HLzgqpkGWzcHAgKWLLauKFA&s','gambar1.png')
# Out:
# ('gambar1.png', <http.client.HTTPMessage at 0x7e78dfba68c0>)

# %% [markdown]
# # Rotasi

# %%
# prompt: please make rotation code using opencv

import cv2
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('gambar1.png')

# Get the image dimensions
height, width = image.shape[:2]

# Define the rotation center
center = (width // 2, height // 2)

# Define the rotation angle (in degrees)
angle = 75

# Get the rotation matrix
rotation_matrix = cv2.getRotationMatrix2D(center, angle, 1.0)

# Perform the rotation
rotated_image = cv2.warpAffine(image, rotation_matrix, (width, height))

# Display the original and rotated images
plt.figure(figsize=(8, 4))

plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("Original Image")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(rotated_image, cv2.COLOR_BGR2RGB))
plt.title("Rotated Image")
plt.axis('off')

plt.show()

# %% [markdown]
# # Dicerminkan

# %%
# prompt: please make code for reflection using opencv

import matplotlib.pyplot as plt
# Load the image
image = cv2.imread('gambar1.png')

# Flip the image horizontally
flipped_horizontal = cv2.flip(image, 1)

# Flip the image vertically
flipped_vertical = cv2.flip(image, 0)

# Flip the image both horizontally and vertically
flipped_both = cv2.flip(image, -1)

# Display the original and flipped images
plt.figure(figsize=(12, 6))

plt.subplot(2, 2, 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("Original Image")
plt.axis('off')

plt.subplot(2, 2, 2)
plt.imshow(cv2.cvtColor(flipped_horizontal, cv2.COLOR_BGR2RGB))
plt.title("Horizontal Flip")
plt.axis('off')

plt.subplot(2, 2, 3)
plt.imshow(cv2.cvtColor(flipped_vertical, cv2.COLOR_BGR2RGB))
plt.title("Vertical Flip")
plt.axis('off')

plt.subplot(2, 2, 4)
plt.imshow(cv2.cvtColor(flipped_both, cv2.COLOR_BGR2RGB))
plt.title("Both Horizontal and Vertical Flip")
plt.axis('off')

plt.show()

# %% [markdown]
# # Translasi

# %%
# prompt: please make code for translation using opencv

import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('gambar1.png')

# Define the translation parameters (x and y shifts)
tx = 50  # Shift along the x-axis
ty = 100  # Shift along the y-axis

# Create the translation matrix
translation_matrix = np.float32([[1, 0, tx], [0, 1, ty]])

# Perform the translation
translated_image = cv2.warpAffine(image, translation_matrix, (image.shape[1], image.shape[0]))

# Display the original and translated images
plt.figure(figsize=(8, 4))

plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("Original Image")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(translated_image, cv2.COLOR_BGR2RGB))
plt.title("Translated Image")
plt.axis('off')

plt.show()

# %% [markdown]
# # Blur

# %%
# prompt: please make code to blur image using opencv

import cv2
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('gambar1.png')

# Apply Gaussian blur
blurred_image = cv2.GaussianBlur(image, (5, 5), 0)  # Adjust kernel size (5, 5) for blur level

# Display the original and blurred images
plt.figure(figsize=(8, 4))

plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("Original Image")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(blurred_image, cv2.COLOR_BGR2RGB))
plt.title("Blurred Image")
plt.axis('off')

plt.show()
